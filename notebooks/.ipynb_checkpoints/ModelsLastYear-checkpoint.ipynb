# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm.notebook import tqdm

from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score, mean_squared_error
  
plt.style.use('ggplot')

# %%
# os.makedirs('DataLagsMayPklNew', exist_ok=True)
# df = pd.DataFrame()
# for filename in tqdm(os.listdir('DataLagsMay/')):
#     if '.csv' in filename and filename.replace("csv", "pkl") not in os.listdir('DataLagsMayPklNew'):
#         data = pd.read_csv(f'DataLagsMay/{filename}')
#         data.to_pickle(f'DataLagsMayPklNew/{filename.replace("csv", "pkl")}', protocol=2)
# #         df = pd.concat([df, data])

# %% [markdown]
# ## Read data

# %%
N_READ_FILES = 10

df = pd.DataFrame()
for filename in tqdm(os.listdir('DataLagsMayPklNew/')[:N_READ_FILES]):
    if '.pkl' in filename:
        data = pd.read_pickle(f'DataLagsMayPklNew/{filename}')
        ## Leave only last year
        data = data[data['period_start_dt'] > '2018-10-01']
        df = pd.concat([df, data])
        
df = df.reset_index(drop=True)
print(df.shape)
df_sample = df.copy()

location_dict = pd.read_csv('LOCATION.csv', sep=';').rename(
    columns={
        'STORE_LOCATION_RK': 'store_location_rk',
        'STORE_LOCATION_LVL_RK3': 'city',
        'STORE_LOCATION_LVL_RK2': 'region'
    }
)

data = df_sample.merge(location_dict[['store_location_rk', 'city', 'region']], how='left', on='store_location_rk')

assert data['city'].isna().sum() == 0
assert data['region'].isna().sum() == 0

data.shape
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# (1462143, 140)
# (1462143, 142)

# %%
data['period_start_dt'].max()
# Out:
# '2019-12-30'

# %%
dataTest['period_start_dt'].unique()
# Out:
# array(['2019-10-07', '2019-10-21', '2019-10-28', '2019-11-04',
#        '2019-11-11', '2019-11-18', '2019-11-25', '2019-12-02',
#        '2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30'],
#       dtype=object)

# %%
train_split_date = '2019-11-04'

dataTrain = data[data['period_start_dt'] <= train_split_date]
dataTest = data[data['period_start_dt'] > train_split_date]


print(f'Train contains {round(dataTrain.shape[0] / data.shape[0], 2) * 100}% of data - {dataTrain.shape[0]} rows')
print(f'Test contains {round(dataTest.shape[0] / data.shape[0], 2) * 100}% of data - {dataTest.shape[0]} rows')
# Out:
# Train contains 86.0% of data - 1261869 rows
# Test contains 14.000000000000002% of data - 200274 rows

# %%
main_cols = ['product_rk', 'store_location_rk', 'PROMO1_FLAG', 'PROMO2_FLAG', 'PROMO12_FLAG', 'city']
lag_cols = dataTrain.columns[(dataTrain.columns.str.contains('demand_')) & (~dataTrain.columns.str.contains('lag4'))]

train_cols = main_cols + list(lag_cols)

X_train, y_train = dataTrain[train_cols].values, dataTrain['demand']
X_test, y_test = dataTest[train_cols].values, dataTest['demand']

# %% [markdown]
# # Models

# %% [markdown]
# ## Dummy

# %%
mean_squared_error(np.ones(dataTest.shape[0]) * dataTrain['demand'].mean(), dataTest['demand'])
# Out:
# 9.505683743082962

# %% [markdown]
# ## 1 for all model

# %%
def get_best_params(X_train, y_train):

    model = CatBoostRegressor(iterations=100, verbose=0)

    grid = {
        'learning_rate': [0.01, 0.05, 0.1],
        'depth': [2, 4, 6, 8]
    }

    grid_search_result = model.grid_search(grid, X=X_train, y=y_train)
    
    return grid_search_result['params']

# %%
best_params = get_best_params(X_train, y_train)

model1forAll = CatBoostRegressor(iterations=100, **best_params, verbose=0)
# model1forAll = CatBoostRegressor(iterations=100, verbose=0)
model1forAll.fit(X_train, y_train)
preds = model1forAll.predict(X_test)
mse = mean_squared_error(preds, y_test)
print('Error without clustering:', mse)
# Out:
# bestTest = 2.528234911
# bestIteration = 99
#
# 0:	loss: 2.5282349	best: 2.5282349 (0)	total: 9.26s	remaining: 1m 41s
#
# bestTest = 2.327616158
# bestIteration = 99
#
# 1:	loss: 2.3276162	best: 2.3276162 (1)	total: 17.3s	remaining: 1m 26s
#
# bestTest = 2.301510655
# bestIteration = 99
#
# 2:	loss: 2.3015107	best: 2.3015107 (2)	total: 26.8s	remaining: 1m 20s
#
# bestTest = 2.469876581
# bestIteration = 99
#
# 3:	loss: 2.4698766	best: 2.3015107 (2)	total: 36.1s	remaining: 1m 12s
#
# bestTest = 2.294974351
# bestIteration = 99
#
# 4:	loss: 2.2949744	best: 2.2949744 (4)	total: 45.6s	remaining: 1m 3s
#
# bestTest = 2.278780123
# bestIteration = 97
#
# 5:	loss: 2.2787801	best: 2.2787801 (5)	total: 53.9s	remaining: 53.9s
#
# bestTest = 2.453054765
# bestIteration = 99
#
# 6:	loss: 2.4530548	best: 2.2787801 (5)	total: 1m 5s	remaining: 46.8s
#
# bestTest = 2.288214513
# bestIteration = 98
#
# 7:	loss: 2.2882145	best: 2.2787801 (5)	total: 1m 16s	remaining: 38.4s
#
# bestTest = 2.267038711
# bestIteration = 99
#
# 8:	loss: 2.2670387	best: 2.2670387 (8)	total: 1m 27s	remaining: 29.2s
#
# bestTest = 2.44230101
# bestIteration = 99
#
# 9:	loss: 2.4423010	best: 2.2670387 (8)	total: 1m 47s	remaining: 21.4s
#
# bestTest = 2.276023315
# bestIteration = 99
#
# 10:	loss: 2.2760233	best: 2.2670387 (8)	total: 2m 9s	remaining: 11.8s
#
# bestTest = 2.257655569
# bestIteration = 99
#
# 11:	loss: 2.2576556	best: 2.2576556 (11)	total: 2m 25s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 1.997921911
# bestIteration = 37
#
# Training on fold [1/3]
#
# bestTest = 2.031845929
# bestIteration = 88
#
# Training on fold [2/3]
#
# bestTest = 2.397768213
# bestIteration = 98
#
# Error without clustering: 6.556574787208149

# %% [markdown]
# ### Agglomerative clustering by City column

# %%
## calculate mean demand for every pair product-city

demandByCity = pd.pivot_table(dataTrain.groupby(['product_rk', 'city'])['demand'].mean().reset_index(), 
                                      index='product_rk', values='demand', columns='city', fill_value=0).rename_axis(None, axis=1)
demandByCity.columns = demandByCity.columns.astype(str)
demandByCity.head()
# Out:
#                   32        39        54       189       203       219
# product_rk
# 11478       0.000000  0.000000  0.000000  0.327191  0.484984  0.610929
# 11506       0.000000  0.000000  0.000000  0.634120  0.220969  0.181542
# 11530       0.000000  0.000000  0.000000  0.145257  0.299963  0.420831
# 11549       0.226528  0.504099  0.416438  0.370414  0.410390  0.549081
# 11559       0.000000  0.000000  0.000000  0.315574  0.656122  0.000000

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
agcl =  AgglomerativeClustering(distance_threshold=0, n_clusters=None)
agcl = agcl.fit(demandByCity)
plot_dendrogram(agcl, truncate_mode="level", p=3)

# %% [markdown]
# **Silhouette score** aka Silhouette Coefficient is an evaluation metric that results in the range of -1 to 1. A score near 1 signifies the best importance that the data point is very compact within the cluster to which it belongs and far away from the other clusters. The score near -1 signifies the least or worst importance of the data point. A score near 0 signifies overlapping clusters.
#
# **Davies-Bouldin Index** score is defined as the average similarity measure of each cluster with its most similar cluster, where similarity is the ratio of within-cluster distances to between-cluster distances. Thus, clusters that are farther apart and less dispersed will result in a better score. The minimum score is 0, with lower values indicating better clustering.

# %%
results = pd.DataFrame({'n_clusters': [], 'ss': [], 'dbs': []})
n_clusters = [2, 3, 4, 5, 8, 10, 16, 20]


for i, n_cluster in tqdm(enumerate(n_clusters), total=len(n_clusters)):
    df_cluster = demandByCity.copy()
    agcl = AgglomerativeClustering(n_clusters=n_cluster)
    cluster_labels = agcl.fit_predict(df_cluster)

    df_cluster['label'] = cluster_labels
    ss = silhouette_score(df_cluster.drop('label', axis=1), df_cluster['label'])
    dbs = davies_bouldin_score(df_cluster.drop('label', axis=1), df_cluster['label'])
    
    results.loc[i] = [n_cluster, ss, dbs]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
results
# Out:
#    n_clusters        ss       dbs
# 0         2.0  0.512813  1.093355
# 1         3.0  0.456975  1.032499
# 2         4.0  0.458288  0.999342
# 3         5.0  0.177977  1.349789
# 4         8.0  0.200807  1.488814
# 5        10.0  0.209047  1.370871
# 6        16.0  0.221718  1.356673
# 7        20.0  0.227561  1.291553

# %%
plt.plot(results['n_clusters'], results['ss'])

# %%
plt.plot(results['n_clusters'], results['dbs'])

# %%
## how to define number of clusters?

N_CLUSTERS = 2
agcl =  AgglomerativeClustering(n_clusters=N_CLUSTERS)
cluster_labels = agcl.fit_predict(demandByCity)

## add labels to dataset
demandByCity['label'] = cluster_labels
dataClustered = data.merge(demandByCity.reset_index()[['product_rk', 'label']], on='product_rk', how='left')
dataClustered = dataClustered.sort_values('period_start_dt')
dataClustered.head()
# Out:
#         product_rk  store_location_rk period_start_dt    demand  PROMO1_FLAG  \
# 0            93157               1143      2018-10-08  1.000000          1.0
# 868304       94207                637      2018-10-08  0.040462          0.0
# 868303       97674                637      2018-10-08  0.421687          0.0
# 868302       40149                637      2018-10-08  1.000000          1.0
# 868301       95909                637      2018-10-08  0.507042          1.0
#
#         PROMO2_FLAG  PRICE_REGULAR  PRICE_AFTER_DISC  NUM_CONSULTANT  \
# 0               0.0         4514.0           2257.00             0.0
# 868304          0.0         2199.0           1649.25             0.0
# 868303          0.0          449.0            449.00             0.0
# 868302          0.0         4149.0           2696.95             0.0
# 868301          0.0         4899.0           1633.00             0.0
#
#         AUTORIZATION_FLAG  ...  \
# 0                     1.0  ...
# 868304                1.0  ...
# 868303                1.0  ...
# 868302                1.0  ...
# 868301                1.0  ...
#
#         demand_lag52_w28D_keyproduct_rk_store_location_rk_preagmean_agmedian_NO_FILTER_dynamic_rolling  \
# 0                                                0.179487
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.000000
# 868301                                           2.500000
#
#         demand_lag52_w56D_keyproduct_rk_store_location_rk_preagmean_agmean_NO_FILTER_dynamic_rolling  \
# 0                                                0.159502
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.000000
# 868301                                           1.875542
#
#         demand_lag52_w56D_keyproduct_rk_store_location_rk_preagmean_agmedian_NO_FILTER_dynamic_rolling  \
# 0                                                0.179487
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.000000
# 868301                                           2.000000
#
#         demand_lag52_w182D_keyproduct_rk_store_location_rk_preagmean_agmean_NO_FILTER_dynamic_rolling  \
# 0                                                0.279573
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.500000
# 868301                                           2.006727
#
#         demand_lag52_w182D_keyproduct_rk_store_location_rk_preagmean_agmedian_NO_FILTER_dynamic_rolling  \
# 0                                                0.179487
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.000000
# 868301                                           1.729730
#
#         demand_lag52_w364D_keyproduct_rk_store_location_rk_preagmean_agmean_NO_FILTER_dynamic_rolling  \
# 0                                                0.586418
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           2.081967
# 868301                                           2.006727
#
#         demand_lag52_w364D_keyproduct_rk_store_location_rk_preagmean_agmedian_NO_FILTER_dynamic_rolling  \
# 0                                                0.188914
# 868304                                                NaN
# 868303                                                NaN
# 868302                                           1.000000
# 868301                                           1.729730
#
#         city  region  label
# 0         39      10    0.0
# 868304    54      10    1.0
# 868303    54      10    1.0
# 868302    54      10    1.0
# 868301    54      10    0.0
#
# [5 rows x 143 columns]

# %%
dataClustered['label'].value_counts(normalize=True)
# Out:
# 1.0    0.616792
# 0.0    0.383208
# Name: label, dtype: float64

# %%
dataClustered.groupby(['city', 'label'])['demand'].count().unstack().plot.bar(stacked=True)
# Out:
# <Axes: xlabel='city'>

# %%
## now with labels

train_split_date = '2019-10-01'

dataClusteredTrain = dataClustered[dataClustered['period_start_dt'] <= train_split_date]
dataClusteredTest = dataClustered[dataClustered['period_start_dt'] > train_split_date]


print(f'Train contains {round(dataClusteredTrain.shape[0] / dataClustered.shape[0], 2) * 100}% of data')
print(f'Test contains {round(dataClusteredTest.shape[0] / dataClustered.shape[0], 2) * 100}% of data')
dataClusteredTrain.shape, dataClusteredTest.shape
# Out:
# Train contains 80.0% of data
# Test contains 20.0% of data
# ((1166757, 143), (295386, 143))

# %%
# main_cols = ['product_rk', 'store_location_rk', 'PROMO1_FLAG', 'PROMO2_FLAG', 'PROMO12_FLAG', 'city']
# lag_cols = dataClusteredTrain.columns[dataClusteredTrain.columns.str.contains('demand_')]

# train_cols = main_cols + list(lag_cols)

# X_train, y_train = dataClusteredTrain[train_cols].values, dataClusteredTrain['demand']
# X_test, y_test = dataClusteredTest[train_cols].values, dataClusteredTest['demand']

# %% [markdown]
# ### Predictions

# %%
dataClusteredTest['label'].isna().sum()
# Out:
# 5163

# %% [markdown]
# 11 к строк оказались некластеризованными, предскажем их общей моделью

# %%
mse_sum = 0
mseResults = {}

for label in dataClusteredTrain['label'].unique():
    
    X_train, y_train = dataClusteredTrain[dataClusteredTrain['label'] == label]\
            [train_cols].values, dataClusteredTrain[dataClusteredTrain['label'] == label]['demand']
    
    X_test, y_test = dataClusteredTest[dataClusteredTest['label'] == label]\
            [train_cols].values, dataClusteredTest[dataClusteredTest['label'] == label]['demand']
    
    
    best_params = get_best_params(X_train, y_train)

    cat = CatBoostRegressor(iterations=100, **best_params, verbose=0)
#     cat = CatBoostRegressor(iterations=100, verbose=0)
    cat.fit(X_train, y_train)
    
    preds = cat.predict(X_test)
    err = mean_squared_error(preds, y_test)
    mseResults[label] = err
    mse_sum += err * X_test.shape[0]
    
dataRest = dataClusteredTest[dataClusteredTest['label'].isna()]
X_test, y_test = dataRest[train_cols].values, dataRest['demand']

preds = model1forAll.predict(X_test)
err = mean_squared_error(preds, y_test)
mseResults['noCLuster'] = err
mse_sum += err * X_test.shape[0]
# Out:
# bestTest = 3.500730848
# bestIteration = 99
#
# 0:	loss: 3.5007308	best: 3.5007308 (0)	total: 4.65s	remaining: 51.2s
#
# bestTest = 3.223494004
# bestIteration = 99
#
# 1:	loss: 3.2234940	best: 3.2234940 (1)	total: 8.01s	remaining: 40s
#
# bestTest = 3.198584591
# bestIteration = 98
#
# 2:	loss: 3.1985846	best: 3.1985846 (2)	total: 10.9s	remaining: 32.8s
#
# bestTest = 3.429988299
# bestIteration = 99
#
# 3:	loss: 3.4299883	best: 3.1985846 (2)	total: 14.5s	remaining: 29s
#
# bestTest = 3.183647699
# bestIteration = 99
#
# 4:	loss: 3.1836477	best: 3.1836477 (4)	total: 18.3s	remaining: 25.6s
#
# bestTest = 3.154248942
# bestIteration = 98
#
# 5:	loss: 3.1542489	best: 3.1542489 (5)	total: 22.1s	remaining: 22.1s
#
# bestTest = 3.405770432
# bestIteration = 99
#
# 6:	loss: 3.4057704	best: 3.1542489 (5)	total: 28s	remaining: 20s
#
# bestTest = 3.161960584
# bestIteration = 99
#
# 7:	loss: 3.1619606	best: 3.1542489 (5)	total: 33.5s	remaining: 16.8s
#
# bestTest = 3.159985274
# bestIteration = 93
#
# 8:	loss: 3.1599853	best: 3.1542489 (5)	total: 39.9s	remaining: 13.3s
#
# bestTest = 3.395511666
# bestIteration = 99
#
# 9:	loss: 3.3955117	best: 3.1542489 (5)	total: 46.7s	remaining: 9.35s
#
# bestTest = 3.166132105
# bestIteration = 94
#
# 10:	loss: 3.1661321	best: 3.1542489 (5)	total: 60s	remaining: 5.45s
#
# bestTest = 3.129117493
# bestIteration = 95
#
# 11:	loss: 3.1291175	best: 3.1291175 (11)	total: 1m 7s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 3.61024408
# bestIteration = 97
#
# Training on fold [1/3]
#
# bestTest = 3.286148441
# bestIteration = 99
#
# Training on fold [2/3]
#
# bestTest = 3.313089526
# bestIteration = 71
#
#
# bestTest = 0.7602869605
# bestIteration = 99
#
# 0:	loss: 0.7602870	best: 0.7602870 (0)	total: 4.94s	remaining: 54.3s
#
# bestTest = 0.6759082351
# bestIteration = 99
#
# 1:	loss: 0.6759082	best: 0.6759082 (1)	total: 9.05s	remaining: 45.2s
#
# bestTest = 0.6676734822
# bestIteration = 99
#
# 2:	loss: 0.6676735	best: 0.6676735 (2)	total: 13.5s	remaining: 40.5s
#
# bestTest = 0.7394731524
# bestIteration = 99
#
# 3:	loss: 0.7394732	best: 0.6676735 (2)	total: 19s	remaining: 37.9s
#
# bestTest = 0.6657975699
# bestIteration = 99
#
# 4:	loss: 0.6657976	best: 0.6657976 (4)	total: 24.6s	remaining: 34.5s
#
# bestTest = 0.6603316842
# bestIteration = 99
#
# 5:	loss: 0.6603317	best: 0.6603317 (5)	total: 30.5s	remaining: 30.5s
#
# bestTest = 0.7295274753
# bestIteration = 99
#
# 6:	loss: 0.7295275	best: 0.6603317 (5)	total: 39.5s	remaining: 28.2s
#
# bestTest = 0.6608791998
# bestIteration = 99
#
# 7:	loss: 0.6608792	best: 0.6603317 (5)	total: 48s	remaining: 24s
#
# bestTest = 0.655961422
# bestIteration = 99
#
# 8:	loss: 0.6559614	best: 0.6559614 (8)	total: 56.4s	remaining: 18.8s
#
# bestTest = 0.7236998122
# bestIteration = 99
#
# 9:	loss: 0.7236998	best: 0.6559614 (8)	total: 1m 11s	remaining: 14.4s
#
# bestTest = 0.6570292774
# bestIteration = 99
#
# 10:	loss: 0.6570293	best: 0.6559614 (8)	total: 1m 23s	remaining: 7.6s
#
# bestTest = 0.651835359
# bestIteration = 99
#
# 11:	loss: 0.6518354	best: 0.6518354 (11)	total: 1m 34s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 0.6731239817
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 0.6530747218
# bestIteration = 99
#
# Training on fold [2/3]
#
# bestTest = 0.6500745002
# bestIteration = 99

# %%
mse = mse_sum / dataClusteredTest.shape[0]
print('Error with clustering:', mse)
mseResults
# Out:
# Error with clustering: 4.901879121711619
# {0.0: 7.19355985565449,
#  1.0: 0.6667716746462609,
#  'noCLuster': 101.7217548446283}

# %%
dataClusteredTest['label'].value_counts()
# Out:
# 1.0    178492
# 0.0    111731
# Name: label, dtype: int64

# %% [markdown]
# ## clustering only by city

# %%
mse_sum = 0
mseResults = {}

for city_ in dataTrain['city'].unique():
    
    X_train, y_train = dataTrain[dataTrain['city'] == city_]\
            [train_cols].values, dataTrain[dataTrain['city'] == city_]['demand']
    
    X_test, y_test = dataTest[dataTest['city'] == city_]\
            [train_cols].values, dataTest[dataTest['city'] == city_]['demand']
    
    
    best_params = get_best_params(X_train, y_train)

    cat = CatBoostRegressor(iterations=100, **best_params, verbose=0)
    cat.fit(X_train, y_train)
    
    preds = cat.predict(X_test)
    err = mean_squared_error(preds, y_test)
    mseResults[city_] = err
    mse_sum += err * X_test.shape[0]
# Out:
# bestTest = 1.3071725
# bestIteration = 99
#
# 86:	learn: 1.9491676	total: 20.3s	remaining: 3.03s
# 87:	learn: 1.9464070	total: 20.5s	remaining: 2.79s
# 88:	learn: 1.9436926	total: 20.7s	remaining: 2.56s
# 89:	learn: 1.9408725	total: 21s	remaining: 2.33s
# 90:	learn: 1.9385121	total: 21.3s	remaining: 2.1s
# 91:	learn: 1.9357970	total: 21.5s	remaining: 1.87s
# 92:	learn: 1.9333939	total: 21.7s	remaining: 1.63s
# 93:	learn: 1.9306942	total: 22s	remaining: 1.4s
# 94:	learn: 1.9285820	total: 22.2s	remaining: 1.17s
# 95:	learn: 1.9261220	total: 22.5s	remaining: 937ms
# 96:	learn: 1.9236664	total: 22.7s	remaining: 702ms
# 97:	learn: 1.9213052	total: 22.9s	remaining: 468ms
# 98:	learn: 1.9192531	total: 23.1s	remaining: 234ms
# 99:	learn: 1.9170507	total: 23.4s	remaining: 0us
#
# bestTest = 2.530815097
# bestIteration = 99
#
# 0:	loss: 2.5308151	best: 2.5308151 (0)	total: 3.06s	remaining: 15.3s
#
# bestTest = 2.487374953
# bestIteration = 97
#
# 1:	loss: 2.4873750	best: 2.4873750 (1)	total: 5.99s	remaining: 12s
#
# bestTest = 2.524603544
# bestIteration = 99
#
# 2:	loss: 2.5246035	best: 2.4873750 (1)	total: 9.73s	remaining: 9.73s
#
# bestTest = 2.498067863
# bestIteration = 99
#
# 3:	loss: 2.4980679	best: 2.4873750 (1)	total: 13.4s	remaining: 6.72s
#
# bestTest = 2.510926294
# bestIteration = 99
#
# 4:	loss: 2.5109263	best: 2.4873750 (1)	total: 41.6s	remaining: 8.32s
#
# bestTest = 2.474343448
# bestIteration = 99
#
# 5:	loss: 2.4743434	best: 2.4743434 (5)	total: 1m 9s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 2.424660853
# bestIteration = 93
#
# Training on fold [1/3]
#
# bestTest = 2.240555122
# bestIteration = 64
#
# Training on fold [2/3]
#
# bestTest = 2.463470967
# bestIteration = 93
#
# 0:	learn: 2.9186196	total: 336ms	remaining: 33.3s
# 1:	learn: 2.8357889	total: 2.11s	remaining: 1m 43s
# 2:	learn: 2.7629490	total: 2.99s	remaining: 1m 36s
# 3:	learn: 2.6983531	total: 3.57s	remaining: 1m 25s
# 4:	learn: 2.6427688	total: 3.96s	remaining: 1m 15s
# 5:	learn: 2.5944396	total: 4.41s	remaining: 1m 9s
# 6:	learn: 2.5500945	total: 4.75s	remaining: 1m 3s
# 7:	learn: 2.5105824	total: 5.09s	remaining: 58.6s
# 8:	learn: 2.4772913	total: 5.43s	remaining: 54.9s
# 9:	learn: 2.4473113	total: 5.75s	remaining: 51.8s
# 10:	learn: 2.4195588	total: 6.07s	remaining: 49.1s
# 11:	learn: 2.3961580	total: 6.42s	remaining: 47.1s
# 12:	learn: 2.3754712	total: 6.74s	remaining: 45.1s
# 13:	learn: 2.3561609	total: 7.05s	remaining: 43.3s
# 14:	learn: 2.3367175	total: 7.39s	remaining: 41.9s
# 15:	learn: 2.3194184	total: 7.71s	remaining: 40.5s
# 16:	learn: 2.3036817	total: 8.05s	remaining: 39.3s
# 88:	learn: 1.0914645	total: 13.2s	remaining: 1.63s
# 89:	learn: 1.0897603	total: 13.3s	remaining: 1.48s
# 90:	learn: 1.0886477	total: 13.4s	remaining: 1.33s
# 91:	learn: 1.0869994	total: 13.6s	remaining: 1.18s
# 92:	learn: 1.0855526	total: 13.7s	remaining: 1.03s
# 93:	learn: 1.0841247	total: 13.9s	remaining: 887ms
# 94:	learn: 1.0831975	total: 14s	remaining: 739ms
# 95:	learn: 1.0784992	total: 14.2s	remaining: 591ms
# 96:	learn: 1.0768651	total: 14.3s	remaining: 443ms
# 97:	learn: 1.0757176	total: 14.5s	remaining: 295ms
# 98:	learn: 1.0740750	total: 14.6s	remaining: 148ms
# 99:	learn: 1.0729904	total: 14.8s	remaining: 0us
#
# bestTest = 1.527698505
# bestIteration = 98
#
# 0:	loss: 1.5276985	best: 1.5276985 (0)	total: 1.3s	remaining: 6.51s
#
# bestTest = 1.482147899
# bestIteration = 94
#
# 1:	loss: 1.4821479	best: 1.4821479 (1)	total: 2.33s	remaining: 4.66s
#
# bestTest = 1.549794581
# bestIteration = 99
#
# 2:	loss: 1.5497946	best: 1.4821479 (1)	total: 4.13s	remaining: 4.13s
#
# bestTest = 1.503547592
# bestIteration = 86
#
# 3:	loss: 1.5035476	best: 1.4821479 (1)	total: 6.06s	remaining: 3.03s
#
# bestTest = 1.551657466
# bestIteration = 99
#
# 4:	loss: 1.5516575	best: 1.4821479 (1)	total: 22.8s	remaining: 4.56s
#
# bestTest = 1.512473618
# bestIteration = 86
#
# 5:	loss: 1.5124736	best: 1.4821479 (1)	total: 39.9s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 2.466420161
# bestIteration = 49
#
# Training on fold [1/3]
#
# bestTest = 1.48234177
# bestIteration = 23
#
# Training on fold [2/3]
#
# bestTest = 1.565847082
# bestIteration = 38
#
# 0:	learn: 2.0612305	total: 15.7ms	remaining: 1.56s
# 1:	learn: 2.0248962	total: 27.2ms	remaining: 1.33s
# 2:	learn: 1.9944272	total: 37.4ms	remaining: 1.21s
# 3:	learn: 1.9640424	total: 50.8ms	remaining: 1.22s
# 4:	learn: 1.9404879	total: 65ms	remaining: 1.24s
# 5:	learn: 1.9198303	total: 76.4ms	remaining: 1.2s
# 6:	learn: 1.8969978	total: 87.9ms	remaining: 1.17s
# 7:	learn: 1.8765866	total: 99.9ms	remaining: 1.15s
# 8:	learn: 1.8567558	total: 118ms	remaining: 1.19s
# 9:	learn: 1.8409572	total: 131ms	remaining: 1.18s
# 10:	learn: 1.8231789	total: 144ms	remaining: 1.17s
# 11:	learn: 1.8107249	total: 157ms	remaining: 1.15s
# 12:	learn: 1.7997694	total: 170ms	remaining: 1.14s
# 13:	learn: 1.7833453	total: 181ms	remaining: 1.11s
# 14:	learn: 1.7752153	total: 195ms	remaining: 1.1s
# 15:	learn: 1.7619222	total: 207ms	remaining: 1.09s
# 16:	learn: 1.7505871	total: 222ms	remaining: 1.08s
# 17:	learn: 1.7389085	total: 240ms	remaining: 1.09s
# 18:	learn: 1.7289299	total: 255ms	remaining: 1.09s
# 68:	learn: 1.4828981	total: 1.04s	remaining: 467ms
# 69:	learn: 1.4812159	total: 1.05s	remaining: 451ms
# 70:	learn: 1.4789023	total: 1.07s	remaining: 438ms
# 71:	learn: 1.4746854	total: 1.08s	remaining: 422ms
# 72:	learn: 1.4704251	total: 1.1s	remaining: 407ms
# 73:	learn: 1.4683044	total: 1.11s	remaining: 391ms
# 74:	learn: 1.4673003	total: 1.13s	remaining: 378ms
# 75:	learn: 1.4645657	total: 1.15s	remaining: 363ms
# 76:	learn: 1.4602769	total: 1.16s	remaining: 348ms
# 77:	learn: 1.4579960	total: 1.18s	remaining: 333ms
# 78:	learn: 1.4539284	total: 1.2s	remaining: 318ms
# 79:	learn: 1.4522183	total: 1.21s	remaining: 303ms
# 80:	learn: 1.4491753	total: 1.23s	remaining: 287ms
# 81:	learn: 1.4461068	total: 1.24s	remaining: 272ms
# 82:	learn: 1.4438337	total: 1.25s	remaining: 256ms
# 83:	learn: 1.4396845	total: 1.26s	remaining: 241ms
# 84:	learn: 1.4374340	total: 1.28s	remaining: 226ms
# 85:	learn: 1.4345459	total: 1.29s	remaining: 210ms
# 86:	learn: 1.4335591	total: 1.31s	remaining: 196ms
# 87:	learn: 1.4324748	total: 1.33s	remaining: 181ms
# 88:	learn: 1.4295889	total: 1.34s	remaining: 166ms
# 89:	learn: 1.4281458	total: 1.36s	remaining: 151ms
# 90:	learn: 1.4269589	total: 1.37s	remaining: 136ms
# 91:	learn: 1.4252625	total: 1.39s	remaining: 121ms
# 92:	learn: 1.4227761	total: 1.4s	remaining: 105ms
# 93:	learn: 1.4189753	total: 1.41s	remaining: 90.3ms
# 94:	learn: 1.4172391	total: 1.43s	remaining: 75.4ms
# 95:	learn: 1.4134461	total: 1.44s	remaining: 60.2ms
# 96:	learn: 1.4095758	total: 1.46s	remaining: 45.1ms
# 97:	learn: 1.4078801	total: 1.47s	remaining: 30ms
# 98:	learn: 1.4053296	total: 1.49s	remaining: 15ms
# 99:	learn: 1.4039760	total: 1.51s	remaining: 0us

# %%
mse = mse_sum / dataTest.shape[0]
print('Error with clustering:', mse)
mseResults
# Out:
# Error with clustering: 4.988494494149908
# {39: 1.6177428912583047,
#  203: 4.465377387060256,
#  54: 8.76309060534912,
#  219: 4.571443430652608,
#  32: 2.8778433431207904,
#  189: 5.133960111353299}

# %% [markdown]
# ### Segmentation by Promo flag

# %%
mse_sum = 0
mseResults = {}

for promo_fl in dataTrain['PROMO12_FLAG'].unique():
    
    X_train, y_train = dataTrain[dataTrain['PROMO12_FLAG'] == promo_fl][train_cols].values, dataTrain[dataTrain['PROMO12_FLAG'] == promo_fl]['demand']
    X_test, y_test = dataTest[dataTest['PROMO12_FLAG'] == promo_fl][train_cols].values, dataTest[dataTest['PROMO12_FLAG'] == promo_fl]['demand']
    
    best_params = get_best_params(X_train, y_train)

    cat = CatBoostRegressor(iterations=100, **best_params, verbose=0)
    cat.fit(X_train, y_train)
    
    preds = cat.predict(X_test)
    err = mean_squared_error(preds, y_test)
    mseResults[promo_fl] = err
    mse_sum += err * X_test.shape[0]
# Out:
# bestTest = 2.181587783
# bestIteration = 99
#
# 0:	loss: 2.1815878	best: 2.1815878 (0)	total: 5.86s	remaining: 29.3s
#
# bestTest = 2.115928908
# bestIteration = 99
#
# 1:	loss: 2.1159289	best: 2.1159289 (1)	total: 11.7s	remaining: 23.5s
#
# bestTest = 2.152204502
# bestIteration = 99
#
# 2:	loss: 2.1522045	best: 2.1159289 (1)	total: 18.5s	remaining: 18.5s
#
# bestTest = 2.087608545
# bestIteration = 99
#
# 3:	loss: 2.0876085	best: 2.0876085 (3)	total: 24.8s	remaining: 12.4s
#
# bestTest = 2.109454098
# bestIteration = 99
#
# 4:	loss: 2.1094541	best: 2.0876085 (3)	total: 1m 5s	remaining: 13s
#
# bestTest = 2.050865785
# bestIteration = 98
#
# 5:	loss: 2.0508658	best: 2.0508658 (5)	total: 1m 44s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 2.130515863
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 2.047883114
# bestIteration = 99
#
# Training on fold [2/3]
#
# bestTest = 2.102281611
# bestIteration = 98
#
# 0:	learn: 2.6335896	total: 507ms	remaining: 50.2s
# 1:	learn: 2.5648044	total: 945ms	remaining: 46.3s
# 2:	learn: 2.5035205	total: 1.46s	remaining: 47.1s
# 3:	learn: 2.4523909	total: 2.01s	remaining: 48.3s
# 4:	learn: 2.4075807	total: 2.44s	remaining: 46.3s
# 5:	learn: 2.3695126	total: 3.02s	remaining: 47.4s
# 6:	learn: 2.3359865	total: 3.6s	remaining: 47.8s
# 7:	learn: 2.3071470	total: 4.11s	remaining: 47.3s
# 8:	learn: 2.2823710	total: 4.6s	remaining: 46.5s
# 9:	learn: 2.2610849	total: 5.09s	remaining: 45.8s
# 10:	learn: 2.2423133	total: 5.54s	remaining: 44.8s
# 11:	learn: 2.2261655	total: 6.02s	remaining: 44.1s
# 12:	learn: 2.2120766	total: 6.5s	remaining: 43.5s
# 13:	learn: 2.1986753	total: 6.97s	remaining: 42.8s
# 14:	learn: 2.1849861	total: 7.52s	remaining: 42.6s
# 15:	learn: 2.1755458	total: 7.94s	remaining: 41.7s
# 16:	learn: 2.1644975	total: 8.48s	remaining: 41.4s
# 17:	learn: 2.1566944	total: 8.98s	remaining: 40.9s
# 18:	learn: 2.1479267	total: 9.55s	remaining: 40.7s
# 19:	learn: 2.1409238	total: 10s	remaining: 40.1s
# 20:	learn: 2.1344134	total: 10.4s	remaining: 39.3s
# 21:	learn: 2.1273622	total: 10.8s	remaining: 38.4s
# 22:	learn: 2.1205709	total: 11.3s	remaining: 37.8s
# 23:	learn: 2.1142657	total: 11.8s	remaining: 37.4s
# 24:	learn: 2.1094243	total: 12.3s	remaining: 36.8s
# 25:	learn: 2.1040381	total: 12.8s	remaining: 36.5s
# 26:	learn: 2.0980490	total: 13.4s	remaining: 36.1s
# 27:	learn: 2.0943321	total: 13.9s	remaining: 35.6s
# 28:	learn: 2.0891619	total: 14.3s	remaining: 35.1s
# 29:	learn: 2.0840992	total: 14.8s	remaining: 34.6s
# 77:	learn: 1.9487791	total: 37.9s	remaining: 10.7s
# 78:	learn: 1.9469432	total: 38.3s	remaining: 10.2s
# 79:	learn: 1.9447504	total: 38.8s	remaining: 9.7s
# 80:	learn: 1.9434281	total: 39.3s	remaining: 9.21s
# 81:	learn: 1.9414997	total: 39.7s	remaining: 8.72s
# 82:	learn: 1.9397907	total: 40.1s	remaining: 8.21s
# 83:	learn: 1.9369882	total: 40.6s	remaining: 7.72s
# 84:	learn: 1.9345769	total: 41s	remaining: 7.24s
# 85:	learn: 1.9327652	total: 41.5s	remaining: 6.75s
# 86:	learn: 1.9308227	total: 41.9s	remaining: 6.26s
# 87:	learn: 1.9287144	total: 42.4s	remaining: 5.78s
# 88:	learn: 1.9278210	total: 43.1s	remaining: 5.33s
# 89:	learn: 1.9262601	total: 43.7s	remaining: 4.86s
# 90:	learn: 1.9240732	total: 44.2s	remaining: 4.38s
# 91:	learn: 1.9222599	total: 44.7s	remaining: 3.89s
# 92:	learn: 1.9211744	total: 45.2s	remaining: 3.4s
# 93:	learn: 1.9192756	total: 45.7s	remaining: 2.92s
# 94:	learn: 1.9178562	total: 46.3s	remaining: 2.43s
# 95:	learn: 1.9168638	total: 46.8s	remaining: 1.95s
# 96:	learn: 1.9152328	total: 47.3s	remaining: 1.46s
# 97:	learn: 1.9133193	total: 47.9s	remaining: 977ms
# 98:	learn: 1.9116608	total: 48.3s	remaining: 488ms
# 99:	learn: 1.9105866	total: 48.7s	remaining: 0us
#
# bestTest = 1.808075947
# bestIteration = 99
#
# 0:	loss: 1.8080759	best: 1.8080759 (0)	total: 6.89s	remaining: 34.4s
#
# bestTest = 1.77235351
# bestIteration = 91
#
# 1:	loss: 1.7723535	best: 1.7723535 (1)	total: 15.6s	remaining: 31.2s
#
# bestTest = 1.800942869
# bestIteration = 99
#
# 2:	loss: 1.8009429	best: 1.7723535 (1)	total: 24s	remaining: 24s
#
# bestTest = 1.770486818
# bestIteration = 69
#
# 3:	loss: 1.7704868	best: 1.7704868 (3)	total: 31.1s	remaining: 15.6s
#
# bestTest = 1.795567004
# bestIteration = 99
#
# 4:	loss: 1.7955670	best: 1.7704868 (3)	total: 1m 20s	remaining: 16.1s
#
# bestTest = 1.771922886
# bestIteration = 92
#
# 5:	loss: 1.7719229	best: 1.7704868 (3)	total: 2m 23s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 2.126888814
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 1.976360536
# bestIteration = 31
#
# Training on fold [2/3]
#
# bestTest = 2.423955783
# bestIteration = 60
#
# 0:	learn: 2.5637296	total: 81.1ms	remaining: 8.03s
# 1:	learn: 2.4998778	total: 151ms	remaining: 7.39s
# 2:	learn: 2.4458140	total: 219ms	remaining: 7.09s
# 3:	learn: 2.3983431	total: 289ms	remaining: 6.95s
# 4:	learn: 2.3579018	total: 365ms	remaining: 6.94s
# 5:	learn: 2.3227667	total: 439ms	remaining: 6.88s
# 6:	learn: 2.2934460	total: 509ms	remaining: 6.76s
# 7:	learn: 2.2675043	total: 581ms	remaining: 6.68s
# 78:	learn: 1.3908403	total: 123ms	remaining: 32.8ms
# 79:	learn: 1.3824584	total: 125ms	remaining: 31.2ms
# 80:	learn: 1.3813447	total: 126ms	remaining: 29.6ms
# 81:	learn: 1.3809257	total: 128ms	remaining: 28.1ms
# 82:	learn: 1.3717346	total: 129ms	remaining: 26.5ms
# 83:	learn: 1.3693234	total: 131ms	remaining: 24.9ms
# 84:	learn: 1.3616954	total: 132ms	remaining: 23.4ms
# 85:	learn: 1.3551930	total: 134ms	remaining: 21.8ms
# 86:	learn: 1.3484457	total: 135ms	remaining: 20.2ms
# 87:	learn: 1.3425844	total: 137ms	remaining: 18.7ms
# 88:	learn: 1.3416138	total: 138ms	remaining: 17.1ms
# 89:	learn: 1.3400288	total: 140ms	remaining: 15.6ms
# 90:	learn: 1.3378157	total: 142ms	remaining: 14ms
# 91:	learn: 1.3369319	total: 143ms	remaining: 12.4ms
# 92:	learn: 1.3339172	total: 145ms	remaining: 10.9ms
# 93:	learn: 1.3334693	total: 146ms	remaining: 9.33ms
# 94:	learn: 1.3310100	total: 148ms	remaining: 7.77ms
# 95:	learn: 1.3287229	total: 149ms	remaining: 6.22ms
# 96:	learn: 1.3222635	total: 151ms	remaining: 4.66ms
# 97:	learn: 1.3204517	total: 152ms	remaining: 3.11ms
# 98:	learn: 1.3189339	total: 154ms	remaining: 1.55ms
# 99:	learn: 1.3141825	total: 155ms	remaining: 0us
# bestTest = 1.328708515
# bestIteration = 99
#
# 0:	loss: 1.3287085	best: 1.3287085 (0)	total: 148ms	remaining: 742ms
#
# bestTest = 1.11328218
# bestIteration = 99
#
# 1:	loss: 1.1132822	best: 1.1132822 (1)	total: 293ms	remaining: 587ms
#
# bestTest = 1.320785713
# bestIteration = 99
#
# 2:	loss: 1.3207857	best: 1.1132822 (1)	total: 714ms	remaining: 714ms
#
# bestTest = 1.08625117
# bestIteration = 99
#
# 3:	loss: 1.0862512	best: 1.0862512 (3)	total: 1.14s	remaining: 571ms
#
# bestTest = 1.318088738
# bestIteration = 99
#
# 4:	loss: 1.3180887	best: 1.0862512 (3)	total: 6.31s	remaining: 1.26s
#
# bestTest = 1.065443048
# bestIteration = 98
#
# 5:	loss: 1.0654430	best: 1.0654430 (5)	total: 11.5s	remaining: 0us
# Estimating final quality...
# Training on fold [0/3]
#
# bestTest = 1.06348233
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 1.192397946
# bestIteration = 91
#
# Training on fold [2/3]
#
# bestTest = 1.185251632
# bestIteration = 99
#
# 0:	learn: 1.5065113	total: 52ms	remaining: 5.14s
# 1:	learn: 1.4742156	total: 107ms	remaining: 5.26s
# 2:	learn: 1.4436849	total: 159ms	remaining: 5.15s
# 3:	learn: 1.4222717	total: 212ms	remaining: 5.08s
# 4:	learn: 1.3959173	total: 264ms	remaining: 5.02s
# 5:	learn: 1.3736120	total: 318ms	remaining: 4.98s
# 6:	learn: 1.3564287	total: 369ms	remaining: 4.91s
# 7:	learn: 1.3374036	total: 425ms	remaining: 4.89s
# 8:	learn: 1.3241245	total: 478ms	remaining: 4.83s
#  3: 8.737832424746655,
#  1: 0.5940452030286323}

# %%
dataTest['PROMO12_FLAG'].value_counts()
# Out:
# 2    185550
# 0    109139
# 3       633
# 1        64
# Name: PROMO12_FLAG, dtype: int64

# %% [markdown]
# ### Horyzont prediction

# %%
dataTest['period_start_dt'].unique()
# Out:
# array(['2019-11-11', '2019-11-18', '2019-11-25', '2019-12-02',
#        '2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30'],
#       dtype=object)

# %%
hor1 = ['2019-11-11', '2019-11-18', '2019-11-25', '2019-12-02']
hor2 = ['2019-12-09', '2019-12-16', '2019-12-23', '2019-12-30']

# %%
mse_sum = 0

# %%
## December

main_cols = ['product_rk', 'store_location_rk', 'PROMO1_FLAG', 'PROMO2_FLAG', 'PROMO12_FLAG', 'city']
lag_cols = dataTrain.columns[(dataTrain.columns.str.contains('demand_'))]

train_cols_all = main_cols + list(lag_cols)

dataTestHorizon = dataTest[dataTest['period_start_dt'].isin(hor2)]
print(dataTrainHorizon.shape, dataTestHorizon.shape)

X_train, y_train = dataTrain[train_cols_all].values, dataTrain['demand']
X_test, y_test = dataTestHorizon[train_cols_all].values, dataTestHorizon['demand']

modelHorizon = CatBoostRegressor(iterations=100, verbose=0)
modelHorizon.fit(X_train, y_train)
preds = modelHorizon.predict(X_test)
mse = mean_squared_error(preds, y_test)
mse_sum += mse * X_test.shape[0]
print('Error for December:', mse)
# Out:
# (1462143, 142) (110996, 142)
# Error for December: 9.829329706572091

# %%
## November

dataTestHorizon = dataTest[dataTest['period_start_dt'].isin(hor1)]
print(dataTrainHorizon.shape, dataTestHorizon.shape)

X_train, y_train = dataTrain[train_cols].values, dataTrain['demand']
X_test, y_test = dataTestHorizon[train_cols].values, dataTestHorizon['demand']

modelHorizon = CatBoostRegressor(iterations=100, verbose=0)
modelHorizon.fit(X_train, y_train)
preds = modelHorizon.predict(X_test)
mse = mean_squared_error(preds, y_test)
mse_sum += mse * X_test.shape[0]
print('Error for November:', mse)
# Out:
# (1462143, 142) (89278, 142)
# Error for November: 2.749922775215253

# %%
# dataTrainHorizon = dataTrain.copy()
# mse_sum = 0

# for hor in tqdm(horizons):
    
#     dataTestHorizon = dataTest[dataTest['period_start_dt'].isin(hor)]
#     print(dataTrainHorizon.shape, dataTestHorizon.shape)
    
#     X_train, y_train = dataTrainHorizon[train_cols].values, dataTrainHorizon['demand']
#     X_test, y_test = dataTestHorizon[train_cols].values, dataTestHorizon['demand']
    
# #     best_params = get_best_params(X_train, y_train)

# #     modelHorizon = CatBoostRegressor(iterations=100, **best_params, verbose=0)
#     modelHorizon = CatBoostRegressor(iterations=100, verbose=0)
#     modelHorizon.fit(X_train, y_train)
#     preds = modelHorizon.predict(X_test)
#     mse = mean_squared_error(preds, y_test)
#     mse_sum += mse * X_test.shape[0]
#     print('Error without clustering:', mse)
    
#     dataTrainHorizon = pd.concat([dataTrainHorizon, dataTestHorizon])

# %%
mse = mse_sum / dataTest.shape[0]
print('Error with horizons:', mse)
# Out:
# Error with horizons: 6.673476765013647
